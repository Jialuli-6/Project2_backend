# %%
# !pip install langchain_google_genai
# Out:
# Collecting langchain_google_genai
#   Downloading langchain_google_genai-4.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from langchain_google_genai) (1.2.0)
# Collecting google-genai<2.0.0,>=1.53.0 (from langchain_google_genai)
#   Downloading google_genai-1.54.0-py3-none-any.whl.metadata (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.8/47.8 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: langchain-core<2.0.0,>=1.1.2 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from langchain_google_genai) (1.1.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from langchain_google_genai) (2.12.4)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /home/jialu/.local/lib/python3.11/site-packages (from google-genai<2.0.0,>=1.53.0->langchain_google_genai) (4.10.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.14.1 in /home/jialu/.local/lib/python3.11/site-packages (from google-auth[requests]<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.53.0->langchain_google_genai) (2.40.3)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /home/jialu/.local/lib/python3.11/site-packages (from google-genai<2.0.0,>=1.53.0->langchain_google_genai) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from google-genai<2.0.0,>=1.53.0->langchain_google_genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in /home/jialu/.local/lib/python3.11/site-packages (from google-genai<2.0.0,>=1.53.0->langchain_google_genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in /home/jialu/.local/lib/python3.11/site-packages (from google-genai<2.0.0,>=1.53.0->langchain_google_genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from google-genai<2.0.0,>=1.53.0->langchain_google_genai) (4.15.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.1.2->langchain_google_genai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.1.2->langchain_google_genai) (0.4.50)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.1.2->langchain_google_genai) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.1.2->langchain_google_genai) (6.0.1)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from langchain-core<2.0.0,>=1.1.2->langchain_google_genai) (0.12.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.0.0->langchain_google_genai) (0.4.2)
# Requirement already satisfied: idna>=2.8 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.53.0->langchain_google_genai) (3.4)
# Requirement already satisfied: sniffio>=1.1 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.53.0->langchain_google_genai) (1.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/jialu/.local/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.53.0->langchain_google_genai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.53.0->langchain_google_genai) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/jialu/.local/lib/python3.11/site-packages (from google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.53.0->langchain_google_genai) (4.9.1)
# Requirement already satisfied: certifi in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.53.0->langchain_google_genai) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /home/jialu/.local/lib/python3.11/site-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.53.0->langchain_google_genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/jialu/.local/lib/python3.11/site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.53.0->langchain_google_genai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.1.2->langchain_google_genai) (2.1)
# Requirement already satisfied: orjson>=3.9.14 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain_google_genai) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain_google_genai) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.1.2->langchain_google_genai) (0.25.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.53.0->langchain_google_genai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.53.0->langchain_google_genai) (2.0.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /scratch/Jli/con/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.14.1->google-auth[requests]<3.0.0,>=2.14.1->google-genai<2.0.0,>=1.53.0->langchain_google_genai) (0.4.8)
# Downloading langchain_google_genai-4.0.0-py3-none-any.whl (63 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 kB 9.9 MB/s eta 0:00:00
# Downloading google_genai-1.54.0-py3-none-any.whl (262 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.4/262.4 kB 20.6 MB/s eta 0:00:00
# Installing collected packages: google-genai, langchain_google_genai
#   Attempting uninstall: google-genai
#     Found existing installation: google-genai 1.34.0
#     Uninstalling google-genai-1.34.0:
#       Successfully uninstalled google-genai-1.34.0
# Successfully installed google-genai-1.54.0 langchain_google_genai-4.0.0

# %%
import json
from typing import Dict, Union, List, Any

import altair as alt
import pandas as pd
from IPython.display import display

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.messages import SystemMessage, HumanMessage

# %% [markdown]
# ### Building basic tools (filtering, analysis, visualization)

# %%
Paper_field_inst = pd.read_csv('/scratch/Jli/Assignment/yeshiva_subset/Paper_field_inst_yu.csv')
Paper_field_inst.head()
# Out:
#        paperid                                        doi  year        date  \
# 0  W4230191490  https://doi.org/10.1080/07908318909525055  1989  1989-01-01
# 1  W4230191490  https://doi.org/10.1080/07908318909525055  1989  1989-01-01
# 2  W4230191490  https://doi.org/10.1080/07908318909525055  1989  1989-01-01
# 3  W4230191490  https://doi.org/10.1080/07908318909525055  1989  1989-01-01
# 4  W4230191490  https://doi.org/10.1080/07908318909525055  1989  1989-01-01
#
#    doctype  cited_by_count  is_retracted  reference_count  citation_count  \
# 0  article               0         False                6               0
# 1  article               0         False                6               0
# 2  article               0         False                6               0
# 3  article               0         False                6               0
# 4  article               0         False                6               0
#
#       fieldid              field  score_openalex author_position     authorid  \
# 0  C144024400          Sociology        0.456282            last  A5108089204
# 1   C29595303      Media studies        0.413342            last  A5108089204
# 2   C17744445  Political science        0.412701            last  A5108089204
# 3  C142362112                Art        0.265091            last  A5108089204
# 4   C52119013        Art history        0.219945            last  A5108089204
#
#   institution_id         institution
# 0      I19772626  Yeshiva University
# 1      I19772626  Yeshiva University
# 2      I19772626  Yeshiva University
# 3      I19772626  Yeshiva University
# 4      I19772626  Yeshiva University

# %%
min_year = Paper_field_inst["year"].min()
max_year = Paper_field_inst["year"].max()
print(min_year, max_year)
# Out:
# 1933 2024

# %%
params = {
    "institution": "Yeshiva University",     
    "field": "computer science",            
    "year_min": "2010",                        
    "year_max": "2024"                         
}

# %%
def apply_defaults(params: Dict[str, Any]) -> Dict[str, Any]:

    institution = params.get("institution")
    # If institution is missing/empty, default to Yeshiva University
    if institution is None or str(institution).strip() == "":
        institution = "Yeshiva University"

    field = params.get("fields")
    # If field is missing/empty, default to "computer science"
    if field is None or str(field).strip() == "":
        fields = "Computer Science"
    if isinstance(field, str):
        field = field

    year_min = params.get("year_min")
    year_max = params.get("year_max")

    return {
        "institution": institution,
        "fields":      fields,
        "year_min":   year_min,
        "year_max":   year_max,
    }

# %%
# Filter tool

def filter_tool(df: pd.DataFrame, params: Dict[str, Any]) -> pd.DataFrame:

    params = apply_defaults(params)
    result = df.copy()

    # Institution filter
    institution = params.get("institution")
    if institution and institution.lower() != "all":
        result = result[
            result["institution"].str.lower() == institution.lower()
        ]

    # Field filter
    field = params.get("field")
    if field and field.lower() != "all":
        result = result[result["field"].str.lower() == field.lower()]

    # Year range filters
    year_min = params.get("year_min")
    if year_min is not None and year_min != "":
        result = result[result["year"] >= int(year_min)]

    year_max = params.get("year_max")
    if year_max is not None and year_max != "":
        result = result[result["year"] <= int(year_max)]

    return result

# %%
# Analysis tool

def analyze_tool(df: pd.DataFrame, group_by: Union[str, List[str]]) -> pd.DataFrame:

    if isinstance(group_by, str):
        group_by = [group_by]

    out = (df.groupby(group_by)["paperid"].nunique().reset_index(name="num_papers").sort_values(group_by))
    return out

# %%
# Visualization tool

def bar_chart(df, x, y, title):
    return {
        "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
        "description": title,
        "data": {"values": df.to_dict(orient="records")},
        "mark": {"type": "bar", "tooltip": True},
        "encoding": {
            "x": {"field": x, "type": "ordinal", "sort": "ascending"},
            "y": {"field": y, "type": "quantitative"},
            "tooltip": [{"field": x}, {"field": y}]
        },
        "title": title
    }


def pie_chart(df, x, y, title):
    return {
        "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
        "description": title,
        "data": {"values": df.to_dict(orient="records")},
        "mark": {"type": "arc", "tooltip": True},
        "encoding": {
            "theta": {"field": y, "type": "quantitative"},
            "color": {"field": x, "type": "nominal"},
            "tooltip": [{"field": x}, {"field": y}]
        },
        "title": title
    }

# %% [markdown]
# ### Building LLM agents

# %%
GEMINI_API_KEY = "AIzaSyA9JT5VGCy441iglboPtQO4fRs6kwcJt_U"
# GEMINI_API_KEY = "AIzaSyBiIOrrYB7LwrVkVPphL8-Dok40ciMPYeo"
# GEMINI_API_KEY = "AIzaSyCDi9tZsjalM-KFo3EU4aI6yJbPIJjag_U"


llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    api_key=GEMINI_API_KEY,
    temperature=0.0,
    max_retries=0,
)

resp = llm.invoke("Hello!")
print(resp.content)
# Out:
# Hello there! How can I help you today?

# %%
# Building a planner LLM agent

PLANNER_SYSTEM_PROMPT = """
You are a planning agent for a SciSciNet data analysis chatbot.

The user will ask questions like:
- "show me the number of papers by year"
- "show me the number of papers by field between 2010 and 2020"
- "for Yeshiva University show me papers by year"

Your job is to output a valid JSON object with no extra text.

JSON schema:
{
  "group_by": "year" | "field" | ["year","field"] | ["field","year"],
  "chart_type": "bar" | "pie",
  "filters": {
    "institution": string or "Yeshiva University",
    "field": [string] or "computer science",
    "year_min": int or "2010",
    "year_max": int or "2024",
  }
}

Rules:
1. Choose group_by based on the user's request. If they mention "by year", use "year". If "by field" or a list of fields, use "field".
2. If the user mentions an institution, use that. Otherwise default to: "Yeshiva University".
3. If the user mentions a specific field or discipline (e.g., "biology", "AI", "economics"), set field to that exact string.
   If they do not mention a field, default to: "computer science".
4. If the user mentions a year range (e.g., 1990-2010), parse year_min and year_max as integers.
   If the user mentions only one year (e.g., "in 2015"), set both year_min and year_max to that year.
   If nothing about years is mentioned, set both year_min to 2010, year_max to 2024.
5. If the user says "bar chart", choose chart_type = "bar". If the user says "pie chart", choose chart_type = "pie".
   If the user does not specify, default chart_type = "bar".
6. Do not explain. Output only JSON file.
"""

def planner_for_user_query(user_query: str) -> Dict[str, Any]:
    messages = [
        SystemMessage(content=PLANNER_SYSTEM_PROMPT),
        HumanMessage(content=user_query)
    ]
    
    resp = llm.invoke(messages)
    print("RAW LLM RESPONSE:", repr(resp.content)) 
    
    raw = resp.content
    if raw is None:
        raise ValueError("LLM returned no content")

    raw = raw.strip()

    start = raw.find("{")
    end   = raw.rfind("}")
    
    json_str = raw[start:end+1]

    try:
        plan = json.loads(json_str)
    except json.JSONDecodeError as e:
        print("JSON FAILED TO PARSE:", json_str)
        raise e

    return plan

# %%
# Building a visualization LLM agent

VISUALIZER_SYSTEM_PROMPT = """
You are a visualization agent that outputs Vega-Lite v6 specifications.

You will receive JSON with the following structure:
{
  "data": [ { ... } ],
  "x_field": string,
  "y_field": string,
  "chart_type": "bar" | "pie",
  "title": string
}

Your job is to return a valid Vega-Lite v6 JSON specification.

Rules:
1. If chart_type="bar":
   - Use a bar chart with:
     {
       "mark": { "type": "bar", "tooltip": true },
       "encoding": {
         "x": { "field": x_field, "type": "ordinal" or "quantitative" },
         "y": { "field": y_field, "type": "quantitative" },
         "tooltip": [...]
       }
     }

2. If chart_type="pie":
   - Use an arc (pie) chart with:
     {
       "mark": { "type": "arc", "tooltip": true },
       "encoding": {
         "theta": { "field": y_field, "type": "quantitative" },
         "color": { "field": x_field, "type": "nominal" },
         "tooltip": [...]
       }
     }

3. Always include:
   "$schema": "https://vega.github.io/schema/vega-lite/v6.json"
   "data": { "values": [...] }
   "title": title

4. Respond with EXACTLY one JSON object, no markdown fences, no explanation.
"""


def planner_for_visualization(df_grouped: pd.DataFrame, x_field: str, y_field: str, chart_type: str, title: str) -> Dict[str, Any]:

    records = df_grouped[[x_field, y_field]].to_dict(orient="records")

    load = {
        "data": records,
        "x_field": x_field,
        "y_field": y_field,
        "chart_type": chart_type,
        "title": title,
    }

    messages = [
        SystemMessage(content=VISUALIZER_SYSTEM_PROMPT),
        HumanMessage(content=json.dumps(load)),
    ]

    resp = llm.invoke(messages)
    raw = resp.content

    raw = str(raw).strip()
    print("RAW VISUALIZER OUTPUT:", repr(raw))

    start = raw.find("{")
    end   = raw.rfind("}")
    raw = raw[start:end+1]

    try:
        spec = json.loads(raw)
    except json.JSONDecodeError as e:
        print("Failed to parse visualizer output:", e)
        print("Raw string was:\n", raw)
        raise

    return spec

# %%
def show_vega_spec(spec: dict):
    chart = alt.Chart.from_dict(spec)
    return chart

# %%
def run_chat_turn(user_query: str, df_base: pd.DataFrame = Paper_field_inst):
    print(f"User: {user_query}\n")

    # 1. Planner: user → plan
    plan = planner_for_user_query(user_query)
    print("Plan:", json.dumps(plan, indent=2))

    group_by = plan["group_by"]
    filters = plan["filters"]

    # 2. Filter
    filtered = filter_tool(df_base, filters)
    grouped = analyze_tool(filtered, group_by)

    # 3. Build title
    field_text = filters.get("field") or "all fields"
    ym = filters.get("year_min") or ""
    yx = filters.get("year_max") or ""
    title = f"Number of papers by {group_by} – Yeshiva University"
    if ym or yx:
        title += f" ({ym}–{yx}), field: {field_text}"

    # 4. Get Vega-Lite spec from visualization LLM
    spec = planner_for_visualization(
        df_grouped=grouped,
        x_field=group_by,
        y_field="num_papers",
        chart_type=plan["chart_type"],
        title=title,
    )

    # 5. Display the chart
    chart = alt.Chart.from_dict(spec)

    display(grouped.head())
    display(chart)

    # return {
    #     "plan": plan,
    #     "filtered": filtered,
    #     "grouped": grouped,
    #     "chart_spec": spec,
    #     "chart": chart,
    # }

# %%
run_chat_turn("show me a bar chart of the number of papers by year")
# Out:
# User: show me a bar chart of the number of papers by year
#
# RAW LLM RESPONSE: '```json\n{\n  "group_by": "year",\n  "chart_type": "bar",\n  "filters": {\n    "institution": "Yeshiva University",\n    "field": "computer science",\n    "year_min": 2010,\n    "year_max": 2024\n  }\n}\n```'
# Plan: {
#   "group_by": "year",
#   "chart_type": "bar",
#   "filters": {
#     "institution": "Yeshiva University",
#     "field": "computer science",
#     "year_min": 2010,
#     "year_max": 2024
#   }
# }
# RAW VISUALIZER OUTPUT: '{"$schema": "https://vega.github.io/schema/vega-lite/v6.json", "data": {"values": [{"year": 2010, "num_papers": 599}, {"year": 2011, "num_papers": 592}, {"year": 2012, "num_papers": 622}, {"year": 2013, "num_papers": 661}, {"year": 2014, "num_papers": 597}, {"year": 2015, "num_papers": 513}, {"year": 2016, "num_papers": 435}, {"year": 2017, "num_papers": 332}, {"year": 2018, "num_papers": 311}, {"year": 2019, "num_papers": 383}, {"year": 2020, "num_papers": 457}, {"year": 2021, "num_papers": 474}, {"year": 2022, "num_papers": 341}, {"year": 2023, "num_papers": 333}, {"year": 2024, "num_papers": 279}]}, "title": "Number of papers by year \\u2013 Yeshiva University (2010\\u20132024), field: computer science", "mark": {"type": "bar", "tooltip": true}, "encoding": {"x": {"field": "year", "type": "ordinal"}, "y": {"field": "num_papers", "type": "quantitative"}, "tooltip": [{"field": "year", "type": "ordinal"}, {"field": "num_papers", "type": "quantitative"}]}}'
#    year  num_papers
# 0  2010         599
# 1  2011         592
# 2  2012         622
# 3  2013         661
# 4  2014         597
# alt.Chart(...)
